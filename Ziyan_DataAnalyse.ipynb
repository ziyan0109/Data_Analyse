# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = 'Questionnaire.csv'
Survey = pd.read_csv(path)

# %%
Survey.head()
# Out:
#                       Timestamp     mbti fav_colour life_value  \
# 0  2024/10/17 12:54:26 PM GMT+1     INTP       blue     family
# 1  2024/10/17 12:58:32 PM GMT+1  No idea        red     family
# 2   2024/10/17 1:02:58 PM GMT+1  No idea      green     family
# 3   2024/10/17 1:06:48 PM GMT+1     ENFJ        red     family
# 4   2024/10/17 1:07:15 PM GMT+1     ENFP       blue     family
#
#            settle_city single_child  comfort_zone parental_relationship  \
# 0  bustling metropolis          yes   by yourself               neutral
# 1           everywhere           no   by yourself              positive
# 2             no place           no  with someone              positive
# 3              coastal           no  with someone              positive
# 4              coastal          yes           NaN               neutral
#
#   childhood_experience parent_contact_frequency        place_grow_up  \
# 0              neutral                    daily  bustling metropolis
# ...

# %%
Survey.mbti.value_counts()
# Out:
# mbti
# No idea    5
# INFP       4
# ENFJ       2
# INFJ       2
# INTP       1
# ENFP       1
# ENTP       1
# ENTJ       1
# INTJ       1
# ISTP       1
# Name: count, dtype: int64

# %%
# How does childhood upbringing influence future preferred settling place?
# Hypothesis - people with positive childhood experiences will tend to settle in similar places, vice versa

# %%
place_grow_up = Survey['place_grow_up'].tolist()
print(place_grow_up)
# Out:
# ['bustling metropolis', 'bustling metropolis', 'countryside village', 'countryside village', 'quiet suburb', 'bustling metropolis', 'quiet suburb', 'coastal', 'coastal', 'bustling metropolis', 'everywhere', 'bustling metropolis', 'Isolated country', 'bustling metropolis', 'bustling metropolis', 'bustling metropolis', 'bustling metropolis', 'bustling metropolis', 'bustling metropolis']

# %%
childhood_experience = Survey['childhood_experience'].tolist()
print(childhood_experience)
# Out:
# ['neutral', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'challenging', 'positive', 'positive', 'positive', 'positive', 'challenging', 'challenging', 'positive', 'neutral', 'neutral', 'positive', 'positive']

# %%
settle_city = Survey['settle_city'].tolist()
print(settle_city)
# Out:
# ['bustling metropolis', 'everywhere', 'no place', 'coastal', 'coastal', 'quiet suburb', 'countryside village', 'bustling metropolis', 'coastal', 'everywhere', 'everywhere', 'bustling metropolis', 'everywhere', 'bustling metropolis', 'everywhere', 'mountain', 'quiet suburb', 'quiet suburb', 'quiet suburb']

# %%
conclusion_02 = list(zip(place_grow_up, childhood_experience, settle_city))
print(conclusion_02)
# Out:
# [('bustling metropolis', 'neutral', 'bustling metropolis'), ('bustling metropolis', 'positive', 'everywhere'), ('countryside village', 'neutral', 'no place'), ('countryside village', 'positive', 'coastal'), ('quiet suburb', 'positive', 'coastal'), ('bustling metropolis', 'positive', 'quiet suburb'), ('quiet suburb', 'positive', 'countryside village'), ('coastal', 'challenging', 'bustling metropolis'), ('coastal', 'positive', 'coastal'), ('bustling metropolis', 'positive', 'everywhere'), ('everywhere', 'positive', 'everywhere'), ('bustling metropolis', 'positive', 'bustling metropolis'), ('Isolated country', 'challenging', 'everywhere'), ('bustling metropolis', 'challenging', 'bustling metropolis'), ('bustling metropolis', 'positive', 'everywhere'), ('bustling metropolis', 'neutral', 'mountain'), ('bustling metropolis', 'neutral', 'quiet suburb'), ('bustling metropolis', 'positive', 'quiet suburb'), ('bustling metropolis', 'positive', 'quiet suburb')]

# %%
count = sum (city for city in conclusion_02 if conclusion_02.split(',')[0] == conclusion_02. split(',')[2])
print (count)
# this part is when I realise I need help and I go ask proud and change another method
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 count = sum (city for city in conclusion_02 if conclusion_02.split(',')[0] == conclusion_02. split(',')[2])
#       2 print (count)
#
# Cell In[19], line 1, in <genexpr>(.0)
# ----> 1 count = sum (city for city in conclusion_02 if conclusion_02.split(',')[0] == conclusion_02. split(',')[2])
#       2 print (count)
#
# AttributeError: 'list' object has no attribute 'split'

# %%
sliced_survey = Survey[['settle_city','childhood_experience','place_grow_up']]
sliced_survey

# Check if middle column is positive or neutral and save to new column
sliced_survey['neutral_positive']= sliced_survey['childhood_experience'].apply(lambda egg:  egg in ['neutral','positive'])
sliced_survey
# Out:
# /var/folders/8t/h_ygnqfn40n6grnn231r3rlm0000gn/T/ipykernel_85855/2013784889.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sliced_survey['neutral_positive']= sliced_survey['childhood_experience'].apply(lambda egg:  egg in ['neutral','positive'])
#             settle_city childhood_experience        place_grow_up  \
# 0   bustling metropolis              neutral  bustling metropolis
# 1            everywhere             positive  bustling metropolis
# 2              no place              neutral  countryside village
# 3               coastal             positive  countryside village
# 4               coastal             positive         quiet suburb
# 5          quiet suburb             positive  bustling metropolis
# ...

# %%
# Filter dataframe so we are only looking at 'neutral_positive' is True and save that to new dataframe

true_survey = sliced_survey[sliced_survey['neutral_positive']==True]
true_survey
# Out:
#             settle_city childhood_experience        place_grow_up  \
# 0   bustling metropolis              neutral  bustling metropolis
# 1            everywhere             positive  bustling metropolis
# 2              no place              neutral  countryside village
# 3               coastal             positive  countryside village
# 4               coastal             positive         quiet suburb
# 5          quiet suburb             positive  bustling metropolis
# 6   countryside village             positive         quiet suburb
# 8               coastal             positive              coastal
# 9            everywhere             positive  bustling metropolis
# 10           everywhere             positive           everywhere
# 11  bustling metropolis             positive  bustling metropolis
# 14           everywhere             positive  bustling metropolis
# 15             mountain              neutral  bustling metropolis
# ...

# %%
# compare 2 columns in a condition and save that as boolean into another column

true_survey['same_place'] = true_survey['place_grow_up'] == true_survey['settle_city']
true_survey
# Out:
# /var/folders/8t/h_ygnqfn40n6grnn231r3rlm0000gn/T/ipykernel_85855/3110368927.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   true_survey['same_place'] = true_survey['place_grow_up'] == true_survey['settle_city']
#             settle_city childhood_experience        place_grow_up  \
# 0   bustling metropolis              neutral  bustling metropolis
# 1            everywhere             positive  bustling metropolis
# 2              no place              neutral  countryside village
# 3               coastal             positive  countryside village
# 4               coastal             positive         quiet suburb
# 5          quiet suburb             positive  bustling metropolis
# ...

# %%
# value count

true_survey['same_place'].value_counts()
# Out:
# same_place
# False    12
# True      4
# Name: count, dtype: int64

# %%
print('number of true:')
true_survey['same_place'].value_counts()[True]

for result in true_survey: 
    if true_survey['same_palce'].value_counts()[True] > true_survey['same_palce'].value_counts()[False]:
        print ('right') else print ('wrong')
# Out:
#   Cell In[77], line 6
#     print ('right') else print ('wrong')
#                     ^
# SyntaxError: invalid syntax

# %%
#import count
 #count function
    
#import pandas 
    #value_count function

# count is another library

# %%
List = ['a', 'b', 'a', 'b', 'a', 'a', 'b', 'b', 'b', 'a', 'b', 'a', 'b', 'a', 'b', 'b', 'b', 'b', 'b']

print List[a].counts()
# Out:
#   Cell In[86], line 3
#     print List[a].counts()
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
